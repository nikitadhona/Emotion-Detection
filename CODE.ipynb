# %%
import cv2

# %%
img = cv2.imread('happyboy.jpg')

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
pip install deepface
# Out:
# Requirement already satisfied: deepface in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (0.0.79)
# Requirement already satisfied: tqdm>=4.30.0 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from deepface) (4.65.0)
# Requirement already satisfied: opencv-python>=4.5.5.64 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from deepface) (4.7.0.72)
# Requirement already satisfied: tensorflow>=1.9.0 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from deepface) (2.12.0)
# Requirement already satisfied: Flask>=1.1.2 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from deepface) (2.1.3)
# Requirement already satisfied: Pillow>=5.2.0 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from deepface) (9.2.0)
# Requirement already satisfied: pandas>=0.23.4 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from deepface) (1.4.3)
# Requirement already satisfied: retina-face>=0.0.1 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from deepface) (0.0.13)
# Requirement already satisfied: keras>=2.2.0 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from deepface) (2.12.0)
# Requirement already satisfied: gunicorn>=20.1.0 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from deepface) (20.1.0)
# Requirement already satisfied: gdown>=3.10.1 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from deepface) (4.7.1)
# Requirement already satisfied: fire>=0.4.0 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from deepface) (0.5.0)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from deepface) (1.23.1)
# Requirement already satisfied: mtcnn>=0.1.0 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from deepface) (0.1.1)
# Requirement already satisfied: six in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from fire>=0.4.0->deepface) (1.16.0)
# Requirement already satisfied: termcolor in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from fire>=0.4.0->deepface) (2.3.0)
# Requirement already satisfied: Werkzeug>=2.0 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from Flask>=1.1.2->deepface) (2.2.1)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from Flask>=1.1.2->deepface) (2.1.2)
# Requirement already satisfied: Jinja2>=3.0 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from Flask>=1.1.2->deepface) (3.1.2)
# Requirement already satisfied: click>=8.0 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from Flask>=1.1.2->deepface) (8.1.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from gdown>=3.10.1->deepface) (4.11.1)
# Requirement already satisfied: requests[socks] in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from gdown>=3.10.1->deepface) (2.28.1)
# Requirement already satisfied: filelock in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from gdown>=3.10.1->deepface) (3.12.0)
# Requirement already satisfied: setuptools>=3.0 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from gunicorn>=20.1.0->deepface) (58.1.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from pandas>=0.23.4->deepface) (2022.2.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from pandas>=0.23.4->deepface) (2.8.2)
# Requirement already satisfied: tensorflow-intel==2.12.0 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from tensorflow>=1.9.0->deepface) (2.12.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow>=1.9.0->deepface) (1.4.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow>=1.9.0->deepface) (1.14.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow>=1.9.0->deepface) (4.22.3)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow>=1.9.0->deepface) (4.5.0)
# Requirement already satisfied: packaging in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow>=1.9.0->deepface) (21.3)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow>=1.9.0->deepface) (2.12.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow>=1.9.0->deepface) (3.3.0)
# Requirement already satisfied: jax>=0.3.15 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow>=1.9.0->deepface) (0.4.8)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow>=1.9.0->deepface) (16.0.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow>=1.9.0->deepface) (3.8.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow>=1.9.0->deepface) (0.4.0)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow>=1.9.0->deepface) (2.12.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow>=1.9.0->deepface) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow>=1.9.0->deepface) (23.3.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow>=1.9.0->deepface) (0.31.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow>=1.9.0->deepface) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow>=1.9.0->deepface) (1.54.0)
# Requirement already satisfied: colorama in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from tqdm>=4.30.0->deepface) (0.4.5)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from Jinja2>=3.0->Flask>=1.1.2->deepface) (2.1.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from beautifulsoup4->gdown>=3.10.1->deepface) (2.3.2.post1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (1.26.12)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (2022.6.15)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (3.3)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (1.7.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.12.0->tensorflow>=1.9.0->deepface) (0.40.0)
# Requirement already satisfied: ml-dtypes>=0.0.3 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow>=1.9.0->deepface) (0.1.0)
# Requirement already satisfied: scipy>=1.7 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow>=1.9.0->deepface) (1.9.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow>=1.9.0->deepface) (3.4.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow>=1.9.0->deepface) (1.0.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow>=1.9.0->deepface) (0.7.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow>=1.9.0->deepface) (2.17.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from packaging->tensorflow-intel==2.12.0->tensorflow>=1.9.0->deepface) (3.0.9)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow>=1.9.0->deepface) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow>=1.9.0->deepface) (0.3.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow>=1.9.0->deepface) (5.3.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow>=1.9.0->deepface) (1.3.1)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow>=1.9.0->deepface) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow>=1.9.0->deepface) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 23.1.2 is available.
# You should consider upgrading via the 'c:\Users\nikit\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
from deepface import DeepFace

# %%
predictions = DeepFace.analyze(img)
# Out:
# Action: race: 100%|██████████| 4/4 [00:03<00:00,  1.11it/s]

# %%
predictions
# Out:
# [{'emotion': {'angry': 1.2530167126101333e-06,
#    'disgust': 2.7825042243471117e-15,
#    'fear': 3.1753016882518637e-08,
#    'happy': 99.87712502479553,
#    'sad': 8.96170249120587e-08,
#    'surprise': 0.0001759753445185197,
#    'neutral': 0.12270037550479174},
#   'dominant_emotion': 'happy',
#   'region': {'x': 39, 'y': 278, 'w': 791, 'h': 791},
#   'age': 31,
#   'gender': {'Woman': 0.37990729324519634, 'Man': 99.62009787559509},
#   'dominant_gender': 'Man',
#   'race': {'asian': 8.432132005691528,
#    'indian': 29.14227843284607,
#    'black': 18.351265788078308,
#    'white': 7.703695446252823,
#    'middle eastern': 7.063188403844833,
#    'latino hispanic': 29.3074369430542},
#   'dominant_race': 'latino hispanic'}]

# %%
predictions[0]['dominant_emotion']
# Out:
# 'happy'

# %%
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
faces = faceCascade.detectMultiScale(gray,1.1,4)

for(x,y,w,h) in faces:
    cv2.rectangle(img, (x,y), (x+w,y+h), (0,255,0), 2)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
font = cv2.FONT_HERSHEY_SIMPLEX

cv2.putText(img,
           predictions[0]['dominant_emotion'],
           (0,50),
           font, 1,
           (0,0,255),
           2,
           cv2.LINE_4);

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
img = cv2.imread('fear.jpg')

# %%
 predictions = DeepFace.analyze(img)
# Out:
# Action: race: 100%|██████████| 4/4 [00:00<00:00,  4.27it/s]

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
predictions
# Out:
# [{'emotion': {'angry': 0.9360349737107754,
#    'disgust': 0.0005040904852648964,
#    'fear': 29.49378192424774,
#    'happy': 0.00595996571064461,
#    'sad': 0.0015179261026787572,
#    'surprise': 69.56220865249634,
#    'neutral': 3.7924273499356786e-06},
#   'dominant_emotion': 'surprise',
#   'region': {'x': 73, 'y': 52, 'w': 216, 'h': 216},
#   'age': 38,
#   'gender': {'Woman': 0.8729142136871815, 'Man': 99.1270899772644},
#   'dominant_gender': 'Man',
#   'race': {'asian': 15.654230117797852,
#    'indian': 13.303011655807495,
#    'black': 2.983405441045761,
#    'white': 9.04657393693924,
#    'middle eastern': 4.3549709022045135,
#    'latino hispanic': 54.65781092643738},
#   'dominant_race': 'latino hispanic'}]

# %%
pip install deepface
# Out:
# Requirement already satisfied: deepface in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (0.0.79)
# Requirement already satisfied: gdown>=3.10.1 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from deepface) (4.7.1)
# Requirement already satisfied: fire>=0.4.0 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from deepface) (0.5.0)
# Requirement already satisfied: gunicorn>=20.1.0 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from deepface) (20.1.0)
# Requirement already satisfied: Flask>=1.1.2 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from deepface) (2.1.3)
# Requirement already satisfied: keras>=2.2.0 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from deepface) (2.12.0)
# Requirement already satisfied: Pillow>=5.2.0 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from deepface) (9.2.0)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from deepface) (1.23.1)
# Requirement already satisfied: tqdm>=4.30.0 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from deepface) (4.65.0)
# Requirement already satisfied: tensorflow>=1.9.0 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from deepface) (2.12.0)
# Requirement already satisfied: pandas>=0.23.4 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from deepface) (1.4.3)
# Requirement already satisfied: mtcnn>=0.1.0 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from deepface) (0.1.1)
# Requirement already satisfied: opencv-python>=4.5.5.64 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from deepface) (4.7.0.72)
# Requirement already satisfied: retina-face>=0.0.1 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from deepface) (0.0.13)
# Requirement already satisfied: six in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from fire>=0.4.0->deepface) (1.16.0)
# Requirement already satisfied: termcolor in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from fire>=0.4.0->deepface) (2.3.0)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from Flask>=1.1.2->deepface) (2.1.2)
# Requirement already satisfied: Werkzeug>=2.0 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from Flask>=1.1.2->deepface) (2.2.1)
# Requirement already satisfied: click>=8.0 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from Flask>=1.1.2->deepface) (8.1.3)
# Requirement already satisfied: Jinja2>=3.0 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from Flask>=1.1.2->deepface) (3.1.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from gdown>=3.10.1->deepface) (4.11.1)
# Requirement already satisfied: requests[socks] in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from gdown>=3.10.1->deepface) (2.28.1)
# Requirement already satisfied: filelock in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from gdown>=3.10.1->deepface) (3.12.0)
# Requirement already satisfied: setuptools>=3.0 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from gunicorn>=20.1.0->deepface) (58.1.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from pandas>=0.23.4->deepface) (2022.2.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from pandas>=0.23.4->deepface) (2.8.2)
# Requirement already satisfied: tensorflow-intel==2.12.0 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from tensorflow>=1.9.0->deepface) (2.12.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow>=1.9.0->deepface) (4.5.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow>=1.9.0->deepface) (0.31.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow>=1.9.0->deepface) (0.2.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow>=1.9.0->deepface) (1.6.3)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow>=1.9.0->deepface) (1.4.0)
# Requirement already satisfied: jax>=0.3.15 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow>=1.9.0->deepface) (0.4.8)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow>=1.9.0->deepface) (2.12.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow>=1.9.0->deepface) (3.3.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow>=1.9.0->deepface) (1.54.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow>=1.9.0->deepface) (0.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow>=1.9.0->deepface) (4.22.3)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow>=1.9.0->deepface) (3.8.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow>=1.9.0->deepface) (16.0.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow>=1.9.0->deepface) (23.3.3)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow>=1.9.0->deepface) (1.14.1)
# Requirement already satisfied: packaging in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow>=1.9.0->deepface) (21.3)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow>=1.9.0->deepface) (2.12.0)
# Requirement already satisfied: colorama in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from tqdm>=4.30.0->deepface) (0.4.5)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from Jinja2>=3.0->Flask>=1.1.2->deepface) (2.1.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from beautifulsoup4->gdown>=3.10.1->deepface) (2.3.2.post1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (2022.6.15)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (1.26.12)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (1.7.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.12.0->tensorflow>=1.9.0->deepface) (0.40.0)
# Requirement already satisfied: scipy>=1.7 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow>=1.9.0->deepface) (1.9.1)
# Requirement already satisfied: ml-dtypes>=0.0.3 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow>=1.9.0->deepface) (0.1.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow>=1.9.0->deepface) (0.7.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow>=1.9.0->deepface) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow>=1.9.0->deepface) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow>=1.9.0->deepface) (3.4.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from packaging->tensorflow-intel==2.12.0->tensorflow>=1.9.0->deepface) (3.0.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow>=1.9.0->deepface) (5.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow>=1.9.0->deepface) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow>=1.9.0->deepface) (0.3.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow>=1.9.0->deepface) (1.3.1)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow>=1.9.0->deepface) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow>=1.9.0->deepface) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 23.1.2 is available.
# You should consider upgrading via the 'c:\Users\nikit\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
import cv2
from deepface import DeepFace
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

cap = cv2.VideoCapture(1)
if not cap.isOpened():
    cap = cv2.VideoCapture(0)
if not cap.isOpened():
    raise IOError("Cannot open webcam")
    
while True:
    ret,frame = cap.read()
    result = DeepFace.analyze(frame, actions = ['emotion'])
    
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces = faceCascade.detectMultiScale(gray,1.1,4)
    
    for(x,y,w,h) in faces:
        cv2.rectangle(frame, (x,y), (x+w, y+h), (0, 255, 0), 2)
        
    font = cv2.FONT_HERSHEY_SIMPLEX
    cv2.putText(frame,
               result[0]['dominant_emotion'],
               (50,50),
               font,3,
               (0,0,255),
               2,
               cv2.LINE_4)
    cv2.imshow('Demo video',frame)
    if cv2.waitKey(2) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 17.65it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 17.10it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 18.29it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 18.27it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 18.66it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 18.04it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 18.23it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 18.23it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 19.22it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 14.96it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 17.27it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 19.24it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 17.98it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 18.05it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 18.86it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 17.61it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00,  9.39it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 18.18it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 18.07it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 16.62it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 18.65it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 16.87it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 18.73it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 19.36it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 17.02it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 20.05it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 18.58it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 17.89it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 18.29it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 18.77it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 18.64it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 18.11it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 19.15it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 16.94it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 18.26it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 19.57it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 15.58it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 18.89it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 18.34it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 18.64it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 18.22it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 16.62it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 14.47it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 19.81it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 18.62it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 19.54it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 18.68it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 16.54it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 18.08it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 18.69it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 19.14it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 18.16it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 18.86it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 19.40it/s]
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 18.74it/s]
